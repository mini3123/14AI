# %%
# 변수는 어떻게 만들까?
# 변수이름 = 변수에 저장할 값

# 변수명 규칙
# 1. 영문자, 숫자, 언더스코어(_) 만 사용할 수 있음
# 2. 숫자로는 시작 안됨
# 3. 예약어(명령어)는 사용할 수 없다.
# 4. 대소문자 구분함

name = "홍길동"
1name ="유재석" #에러
n2ame = "유재석"

user-name = "홍길동" #에러
user_name = "홍길동"

# 컨벤션
# user_name 가능 스네이크 스타일
# UserName 가능 파스칼 표기법
# userName 가능 카멜 표기법

# %%
a = [1,2,3]
print(id(a))
b = [1, 2, 3]
print(id(b))

a.append(4)
print(a)
print(id(a))
# Out:
# 1289708035840
# 1289708120896
# [1, 2, 3, 4]
# 1289708035840

# %%
b = a
print(id(b))
# Out:
# 1289708035840

# %%
a = [1,2,3]
b = a[:]
print(id(a))
print(id(b))
# Out:
# 1289707926592
# 1289708035840

# %%
# 변수를 만드는 여러가지 방법
a , b = ["python","Like"]
print(a)
print(b)
print(type(a))
# Out:
# python
# Like
# <class 'str'>

# %%
(a,b) ="Python","Like"
print(a)
print(b)
print(type(a))
# Out:
# Python
# Like
# <class 'str'>

# %%
a = b = "Python"
print(a)
print(b)
print(type(a))
# Out:
# Python
# Python
# <class 'str'>

# %%
a = 3
b = 5

a,b = b , a
print(a)
print(b)
# Out:
# 5
# 3
