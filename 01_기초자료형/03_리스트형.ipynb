# %%
# 리스트는 어떻게 만들까?
# 형식

a = []
b = [1, 2, 3]
c = ["Life","is","too","short"]
d = [1,2,"Life","is"]
e = [1,2,["Life","is"]]

print(type(a))
print(len(a))
print(len(b))
print(len(c))
print(len(d))
print(len(e))
# Out:
# <class 'list'>
# 0
# 3
# 4
# 4
# 3

# %%
# 리스트의 인덱싱
a = ["Life","is","too","short"]
print(a[0][3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 3
#       1 # 리스트의 인덱싱
#       2 a = [1,2,3]
# ----> 3 print(a in 5)
#
# TypeError: argument of type 'int' is not iterable

# %%
a = [1,2,3]
print(a[0]+a[2])
# Out:
# 4

# %%
a = [1,2,3,["a","b","c"]]
print(a[-1])
print(a[-1][-1])
# Out:
# ['a', 'b', 'c']
# c

# %%
# 리스트 슬라이싱
a = [1,2,3,4,5]
a[0:1+3]
# Out:
# [1, 2, 3, 4]

# %%
# 리스트 연산하기
# 1. 리스트 더하기

a = [1,2,3]
b = [4,5,6]
print(a+b)

# 2. 리스트 곱하기
a = [1,2,3]
b = [4,5,6]
print(a*3)
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
# 리스트의 수정과 삭제
# 1. 리스트의 값 수정하기

a = [1,2,3]
a[2] = 4
print(a)
# 2. 리스트의 요소 삭제하기
a = [1,2,3]
del a[1]
print(a)

a = [1,2,3,4,5]
del a[2:]
print(a)
# Out:
# [1, 2, 4]
# [1, 3]
# [1, 2]

# %%
# 리스트 관련 함수
# 1. 리스트에 요소 추가하기 append

a = [1,2,3]
a.append(5)
print(a)
a.append([5,6])
print(a)
# Out:
# [1, 2, 3, 5]
# [1, 2, 3, 5, [5, 6]]

# %%
# 2. 리스트 정렬 sort
a = [1,4,3,2]
a.sort() #오름차순
a

a = [1,4,3,2]
a.sort(reverse=True) #내림차순 여기서 reverse는 인수로 들어감 (파라미터)
a
# Out:
# [4, 3, 2, 1]

# %%
# 3. 리스트 뒤집기 reverse
a = ["a","c","b"]
# a.sort()
# a
a.reverse()
a
# Out:
# ['b', 'c', 'a']

# %%
# 4. 인덱스 번호 index (글자 위치)

a = [5,4,3,2,1]
print(a.index(3))
print(a.index(2))
# Out:
# 2
# 3

# %%
# 5. 리스트에 요소 삽입 insert

a = [1,2,3]
a.insert(2,2)
a
# Out:
# [1, 2, 2, 3]

# %%
# 6. 리스트 요소 제거 remove

a = [1,2,3,1,2,3]
a.remove(3) #첫번째 요소만 지워줌
a
# Out:
# [1, 2, 1, 2, 3]

# %%
# 7. 리스트 요소 꺼내기 pop
a = [1,2,3]
result1 = a.pop()
print(a)
print(result1)
# Out:
# [1, 2]
# 3

# %%
# 8. 요소의 개수 세기 count
a = [1,2,3,1]
a.count(1)
# Out:
# 2

# %%
# 9. 리스트 확장 extend
a = [1,2,3]
a.extend([4,5])
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
a = [1,2,3]
print(5 in a)
# Out:
# False

# %%
print("b" not in ["a","b","c"])
# Out:
# True

# %%
data = [10, 20, 30, 40, 50]
data[0:3]=1,2,3
data
# Out:
# [1, 2, 3, 40, 50]

# %%
scores = [85, 92, 78, 90, 88, 76, 95, 89]
print(sorted(scores, reverse=True))
# Out:
# [95, 92, 90, 89, 88, 85, 78, 76]

# %%
print("a,b,c,d,e".split(","))
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
a = ["Python", "is", "fun"]
print(" ".join(a))
# Out:
# Python is fun

# %%
a = []
a.append(10)
print(a)
a.append(20)

a.append(30)

a.insert(1,15)

a.extend([40,50])

a
# Out:
# [10]
# [10, 15, 20, 30, 40, 50]

# %%
items = ["a", "b", "c", "b", "d", "b", "e"]
items.remove("b")
items
a = items.pop()
print(items)

b = items.pop(0)
print(items)

items.clear()
print(items)
# Out:
# ['a', 'c', 'b', 'd', 'b']
# ['c', 'b', 'd', 'b']
# []

# %%
data = [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5]
data.count(5)
# Out:
# 3

# %%
numbers = [64, 34, 25, 12, 22, 11, 90]
numbers.sort(reverse=True)
numbers
# Out:
# [90, 64, 34, 25, 22, 12, 11]

# %%
words = ["banana", "Apple", "cherry", "date"]
words.sort()
words
# Out:
# ['Apple', 'banana', 'cherry', 'date']
