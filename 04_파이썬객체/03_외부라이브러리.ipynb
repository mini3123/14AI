# %%
# Do not reinvert the wheel

# %%
from faker import Faker

fake = Faker()
fake.name()
# Out:
# 'Toni Rodriguez'

# %%
fake.address()
# Out:
# 'PSC 1290, Box 0349\nAPO AE 80912'

# %%
test_data = [(fake.name(), fake.address()) for _ in range(30)]
print(test_data)
# Out:
# [('Jessica Hayes', '09949 Jimenez Branch\nWest Sara, MP 37656'), ('Brandy Reilly', '3345 Poole Street\nHoodburgh, NH 38539'), ('Amy Lane', '11470 Martin Run Apt. 019\nNew Cindy, MP 55284'), ('Justin Hart', '52587 Susan Falls Apt. 364\nPort Annaburgh, VA 88805'), ('Abigail York', '48216 Mckinney Flats\nLake Lucas, KS 09621'), ('Christopher Adams', '16550 Roberts Loaf\nKingtown, UT 05827'), ('Stephen Garcia', '26310 Chelsea Pine Suite 428\nGravesland, AZ 80056'), ('Andrea King', '54018 Norris Expressway\nEast Annatown, DC 30327'), ('Benjamin Wong', '110 Wright Extension\nSnydermouth, WI 26204'), ('Jessica Johnson', '9596 Cruz Dale Apt. 731\nWest Reneeside, IL 67821'), ('Erika Smith', '026 Brent Bypass Suite 983\nMontgomeryborough, KY 53624'), ('Melissa Rodriguez', '315 Bowen Spring\nSouth Maria, NE 89130'), ('Nicholas Johnson', '1255 Simon Summit Apt. 123\nLake Vicki, MH 81377'), ('Gregory Torres', '05665 Kevin Ridge\nMilesborough, NY 06907'), ('Megan Anderson', '77313 Joseph View Apt.
# ...
